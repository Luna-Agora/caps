# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import pathlib
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import mapclassify as mc
import numpy as np
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
# %matplotlib inline

# %%
z37072 = pd.read_csv('../data/income by zipcode/37072.csv')
z37076 = pd.read_csv('../data/income by zipcode/37076.csv')
z37115 = pd.read_csv('../data/income by zipcode/37115.csv')
z37138 = pd.read_csv('../data/income by zipcode/37138.csv')
z37189 = pd.read_csv('../data/income by zipcode/37189.csv')
z37201 = pd.read_csv('../data/income by zipcode/37201.csv')
z37203 = pd.read_csv('../data/income by zipcode/37203.csv')
z37204 = pd.read_csv('../data/income by zipcode/37204.csv')
z37205 = pd.read_csv('../data/income by zipcode/37205.csv')
z37206 = pd.read_csv('../data/income by zipcode/37206.csv')
z37207 = pd.read_csv('../data/income by zipcode/37207.csv')
z37208 = pd.read_csv('../data/income by zipcode/37208.csv')
z37209 = pd.read_csv('../data/income by zipcode/37209.csv')
z37210 = pd.read_csv('../data/income by zipcode/37210.csv')
z37211 = pd.read_csv('../data/income by zipcode/37211.csv')
z37212 = pd.read_csv('../data/income by zipcode/37212.csv')
z37213 = pd.read_csv('../data/income by zipcode/37213.csv')
z37214 = pd.read_csv('../data/income by zipcode/37214.csv')
z37215 = pd.read_csv('../data/income by zipcode/37215.csv')
z37216 = pd.read_csv('../data/income by zipcode/37216.csv')
z37217 = pd.read_csv('../data/income by zipcode/37217.csv')
z37218 = pd.read_csv('../data/income by zipcode/37218.csv')
z37219 = pd.read_csv('../data/income by zipcode/37219.csv')
z37220 = pd.read_csv('../data/income by zipcode/37220.csv')
z37221 = pd.read_csv('../data/income by zipcode/37221.csv')
z37228 = pd.read_csv('../data/income by zipcode/37228.csv')

# %%
z072 = z37072[['Label (Grouping)', 'ZCTA5 37072!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z072
# Out:
#                              Label (Grouping) ZCTA5 37072!!Estimate
# 1                Population 16 years and over                26,286
# 4                                    Employed                16,322
# 5                                  Unemployed                   918
# 67          Median household income (dollars)                72,370
# 68            Mean household income (dollars)                94,674

# %%
z076 = z37076[['Label (Grouping)', 'ZCTA5 37076!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z115 = z37115[['Label (Grouping)', 'ZCTA5 37115!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z138 = z37138[['Label (Grouping)', 'ZCTA5 37138!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z189 = z37189[['Label (Grouping)', 'ZCTA5 37189!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z201 = z37201[['Label (Grouping)', 'ZCTA5 37201!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z203 = z37203[['Label (Grouping)', 'ZCTA5 37203!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z204 = z37204[['Label (Grouping)', 'ZCTA5 37204!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z205 = z37205[['Label (Grouping)', 'ZCTA5 37205!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z206 = z37206[['Label (Grouping)', 'ZCTA5 37206!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z207 = z37207[['Label (Grouping)', 'ZCTA5 37207!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z208 = z37208[['Label (Grouping)', 'ZCTA5 37208!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z209 = z37209[['Label (Grouping)', 'ZCTA5 37209!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z210 = z37210[['Label (Grouping)', 'ZCTA5 37210!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z211 = z37211[['Label (Grouping)', 'ZCTA5 37211!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z212 = z37212[['Label (Grouping)', 'ZCTA5 37212!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z213 = z37213[['Label (Grouping)', 'ZCTA5 37213!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z214 = z37214[['Label (Grouping)', 'ZCTA5 37214!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z215 = z37215[['Label (Grouping)', 'ZCTA5 37215!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z216 = z37216[['Label (Grouping)', 'ZCTA5 37216!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z217 = z37217[['Label (Grouping)', 'ZCTA5 37217!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z218 = z37218[['Label (Grouping)', 'ZCTA5 37218!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z219 = z37219[['Label (Grouping)', 'ZCTA5 37219!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z220 = z37220[['Label (Grouping)', 'ZCTA5 37220!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z221 = z37221[['Label (Grouping)', 'ZCTA5 37221!!Estimate']].iloc[[1, 4, 5, 67, 68]]
z228 = z37228[['Label (Grouping)', 'ZCTA5 37228!!Estimate']].iloc[[1, 4, 5, 67, 68]]

# %%
z220
# Out:
#                              Label (Grouping) ZCTA5 37220!!Estimate
# 1                Population 16 years and over                 4,837
# 4                                    Employed                 3,218
# 5                                  Unemployed                    60
# 67          Median household income (dollars)               150,132
# 68            Mean household income (dollars)               230,199

# %%
z076
# Out:
#                              Label (Grouping) ZCTA5 37076!!Estimate
# 1                Population 16 years and over                31,301
# 4                                    Employed                21,257
# 5                                  Unemployed                   805
# 67          Median household income (dollars)                68,894
# 68            Mean household income (dollars)                87,509

# %%
x1 = z072.merge(z076, on=['Label (Grouping)'], how = 'inner')
x1
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate
# 0                31,301
# 1                21,257
# 2                   805
# 3                68,894
# 4                87,509

# %%
x2 = x1.merge(z115, on=['Label (Grouping)'], how = 'inner')
x2
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate
# 0                31,301                33,647
# 1                21,257                21,552
# 2                   805                 1,438
# 3                68,894                55,313
# 4                87,509                69,650

# %%
x3 = x2.merge(z138, on=['Label (Grouping)'], how = 'inner')
x3
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166

# %%
x4 = x3.merge(z189, on=['Label (Grouping)'], how = 'inner')
x4
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate
# 0                 3,338
# 1                 2,324
# 2                   123
# 3                88,804
# 4               108,107

# %%
x5 = x4.merge(z201, on=['Label (Grouping)'], how = 'inner')
x5
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate
# 0                 3,338                 1,443
# 1                 2,324                   971
# ...

# %%
x6 = x5.merge(z203, on=['Label (Grouping)'], how = 'inner')
x6
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate
# 0                 3,338                 1,443                17,629
# ...

# %%
x7 = x6.merge(z204, on=['Label (Grouping)'], how = 'inner')
x7
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x8 = x7.merge(z205, on=['Label (Grouping)'], how = 'inner')
x8
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x9 = x8.merge(z205, on=['Label (Grouping)'], how = 'inner')
x9
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x10 = x9.merge(z206, on=['Label (Grouping)'], how = 'inner')
x10
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x11 = x10.merge(z207, on=['Label (Grouping)'], how = 'inner')
x11
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x12 = x11.merge(z208, on=['Label (Grouping)'], how = 'inner')
x12
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x13 = x12.merge(z209, on=['Label (Grouping)'], how = 'inner')
x13
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x14 = x13.merge(z210, on=['Label (Grouping)'], how = 'inner')
x14
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x15 = x14.merge(z211, on=['Label (Grouping)'], how = 'inner')
x15
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x16 = x15.merge(z212, on=['Label (Grouping)'], how = 'inner')
x16
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x17 = x16.merge(z213, on=['Label (Grouping)'], how = 'inner')
x17
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x18 = x17.merge(z214, on=['Label (Grouping)'], how = 'inner')
x18
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x19 = x18.merge(z215, on=['Label (Grouping)'], how = 'inner')
x19
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x20 = x19.merge(z216, on=['Label (Grouping)'], how = 'inner')
x20
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x21 = x20.merge(z217, on=['Label (Grouping)'], how = 'inner')
x21
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x22 = x21.merge(z218, on=['Label (Grouping)'], how = 'inner')
x22
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x23 = x22.merge(z219, on=['Label (Grouping)'], how = 'inner')
x23
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x24 = x23.merge(z220, on=['Label (Grouping)'], how = 'inner')
x24
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x25 = x24.merge(z221, on=['Label (Grouping)'], how = 'inner')
x25
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
x26 = x25.merge(z228, on=['Label (Grouping)'], how = 'inner')
x26
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
z216.iloc[[1, 5, 6, 67, 68]]
# Out:
#                              Label (Grouping) ZCTA5 37216!!Estimate
# 1                Population 16 years and over                16,092
# 5                                  Unemployed                   428
# 6                                Armed Forces                    39
# 67          Median household income (dollars)                74,693
# 68            Mean household income (dollars)                99,706

# %%
x26
# Out:
#                             Label (Grouping) ZCTA5 37072!!Estimate  \
# 0               Population 16 years and over                26,286
# 1                                   Employed                16,322
# 2                                 Unemployed                   918
# 3          Median household income (dollars)                72,370
# 4            Mean household income (dollars)                94,674
#
#   ZCTA5 37076!!Estimate ZCTA5 37115!!Estimate ZCTA5 37138!!Estimate  \
# 0                31,301                33,647                19,096
# 1                21,257                21,552                12,334
# 2                   805                 1,438                   234
# 3                68,894                55,313                87,465
# 4                87,509                69,650               112,166
#
#   ZCTA5 37189!!Estimate ZCTA5 37201!!Estimate ZCTA5 37203!!Estimate  \
# 0                 3,338                 1,443                17,629
# ...

# %%
z26 = x26.drop(columns=['ZCTA5 37205!!Estimate_y'])

# %%
z26.columns
# Out:
# Index(['Demographics', '37072', '37076', '37115', '37138', '37189', '37201',
#        '37203', '37204', '37205', '37206', '37207', '37208', '37209', '37210',
#        '37211', '37212', '37213', '37214', '37215', '37216', '37217', '37218',
#        '37219', '37220', '37221', '37228'],
#       dtype='object')

# %%
z26 = z26.rename(columns={'Label (Grouping)': 'Demographics', 'ZCTA5 37072!!Estimate': '37072', 'ZCTA5 37076!!Estimate': '37076',
       'ZCTA5 37115!!Estimate': '37115', 'ZCTA5 37138!!Estimate': '37138',
       'ZCTA5 37189!!Estimate': '37189', 'ZCTA5 37201!!Estimate': '37201',
       'ZCTA5 37203!!Estimate': '37203', 'ZCTA5 37204!!Estimate': '37204',
       'ZCTA5 37205!!Estimate_x': '37205', 'ZCTA5 37206!!Estimate': '37206',
       'ZCTA5 37207!!Estimate': '37207', 'ZCTA5 37208!!Estimate': '37208',
       'ZCTA5 37209!!Estimate': '37209', 'ZCTA5 37210!!Estimate': '37210',
       'ZCTA5 37211!!Estimate': '37211', 'ZCTA5 37212!!Estimate': '37212',
       'ZCTA5 37213!!Estimate': '37213', 'ZCTA5 37214!!Estimate': '37214',
       'ZCTA5 37215!!Estimate': '37215', 'ZCTA5 37216!!Estimate': '37216',
       'ZCTA5 37217!!Estimate': '37217', 'ZCTA5 37218!!Estimate': '37218',
       'ZCTA5 37219!!Estimate': '37219', 'ZCTA5 37220!!Estimate': '37220',
       'ZCTA5 37221!!Estimate': '37221', 'ZCTA5 37228!!Estimate': '37228'}, errors="raise")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7424\3096627045.py in ?()
# ----> 1 z26 = z26.rename(columns={'Label (Grouping)': 'Zipcode', 'ZCTA5 37072!!Estimate': '37072', 'ZCTA5 37076!!Estimate': '37076',
#       2        'ZCTA5 37115!!Estimate': '37115', 'ZCTA5 37138!!Estimate': '37138',
#       3        'ZCTA5 37189!!Estimate': '37189', 'ZCTA5 37201!!Estimate': '37201',
#       4        'ZCTA5 37203!!Estimate': '37203', 'ZCTA5 37204!!Estimate': '37204',
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\frame.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5750         0  1  4
#    5751         2  2  5
#    5752         4  3  6
#    5753         """
# -> 5754         return super()._rename(
#    5755             mapper=mapper,
#    5756             index=index,
#    5757             columns=columns,
# ...

# %%
z26
# Out:
#                                 Demographics   37072   37076   37115    37138  \
# 0               Population 16 years and over  26,286  31,301  33,647   19,096
# 1                                   Employed  16,322  21,257  21,552   12,334
# 2                                 Unemployed     918     805   1,438      234
# 3          Median household income (dollars)  72,370  68,894  55,313   87,465
# 4            Mean household income (dollars)  94,674  87,509  69,650  112,166
#
#      37189    37201   37203    37204    37205    37206   37207   37208  \
# 0    3,338    1,443  17,629   14,195   21,762   23,490  31,065  17,880
# 1    2,324      971  12,873   10,803   13,463   17,719  21,146  11,165
# 2      123        0     431      196      238      898   1,181     687
# 3   88,804  106,460  63,834  104,987  136,100   80,915  59,973  59,050
# 4  108,107  137,564  94,336  178,418  222,323  114,377  72,606  86,858
#
# ...

# %%
z26 = z26.rename(columns={'Demographics': 'Zipcode'})

# %%
y26 = z26.transpose().reset_index()
y26
# Out:
#       index                                 0                         1  \
# 0   Zipcode      Population 16 years and over                  Employed
# 1     37072                            26,286                    16,322
# 2     37076                            31,301                    21,257
# 3     37115                            33,647                    21,552
# 4     37138                            19,096                    12,334
# 5     37189                             3,338                     2,324
# 6     37201                             1,443                       971
# 7     37203                            17,629                    12,873
# 8     37204                            14,195                    10,803
# 9     37205                            21,762                    13,463
# 10    37206                            23,490                    17,719
# 11    37207                            31,065                    21,146
# ...

# %%
y26.columns = y26.iloc[0]

# %%
y26 = y26.iloc[1:]

# %%
y26 = y26.reset_index()

# %%
y26
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 y26
#
# NameError: name 'y26' is not defined

# %%
z26.to_csv('census_income_clean.csv', index=False)

# %%
y26.to_csv('census_income_flipped_clean.csv', index=False)

# %%
yframe = pd.read_csv('census_income_flipped_clean.csv')
yframe.columns = yframe.iloc[0]
yframe = yframe.iloc[1:]

# %%
yframe['Zipcode'] = yframe['Zipcode'].astype(np.int64)

# %%
yframe = yframe.reset_index()

# %%
area = pd.read_csv('../area score result.csv')
area = area.rename(columns={'zipcode' : 'Zipcode'})

# %%
area['Zipcode'] = area['Zipcode'].astype(np.int64)

# %%
yframe.Zipcode
# Out:
# 0     37072
# 1     37076
# 2     37115
# 3     37138
# 4     37189
# 5     37201
# 6     37203
# 7     37204
# 8     37205
# 9     37206
# 10    37207
# 11    37208
# 12    37209
# 13    37210
# 14    37211
# 15    37212
# 16    37213
# 17    37214
# 18    37215
# 19    37216
# 20    37217
# 21    37218
# 22    37219
# 23    37220
# 24    37221
# 25    37228
# Name: Zipcode, dtype: int64

# %%
omg = area.merge(yframe)

# %%
omg.str.strip
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 omg.rename(columns=lambda x: x.strip(), inplace=True)
#       2 print(omg)
#
# AttributeError: 'NoneType' object has no attribute 'rename'

# %%
omg.rename(columns=lambda x: x.strip(), inplace=True)

# %%
omg.astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 omg.astype(np.int64)
#
# File ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
omg.rename(columns={'Population 16 years and over' : 'pop_over_16',
       'Employed' : "employed", 'Unemployed' : 'unemployed',
       'Median household income (dollars)' : 'median_income',
       'Mean household income (dollars)': 'avg_income'}, errors='raise')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2372\1802107629.py in ?()
# ----> 1 omg.rename(columns={'Population 16 years and over' : 'pop_over_16',
#       2        'Employed' : "employed", 'Unemployed' : 'unemployed',
#       3        'Median household income (dollars)' : 'median_income',
#       4        'Mean household income (dollars)': 'avg_income'}, errors='raise')
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\frame.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5750         0  1  4
#    5751         2  2  5
#    5752         4  3  6
#    5753         """
# -> 5754         return super()._rename(
#    5755             mapper=mapper,
#    5756             index=index,
#    5757             columns=columns,
#
# ...

# %%
omg['Mean household income (dollars)']
# Out:
# 0      94,674
# 1      87,509
# 2      69,650
# 3     112,166
# 4     108,107
# 5     137,564
# 6      94,336
# 7     178,418
# 8     222,323
# 9     114,377
# 10     72,606
# 11     86,858
# 12     98,701
# 13     68,462
# 14     84,503
# 15    178,515
# 16          N
# 17     87,408
# 18    217,318
# 19     99,706
# 20     72,426
# 21     77,147
# 22     99,317
# 23    230,199
# 24    122,269
# 25    120,574
# Name: Mean household income (dollars), dtype: object

# %%
omg.columns
# Out:
# Index(['Zipcode', 'score', 'index', 'Population 16 years and over', 'Employed',
#        'Unemployed', 'Median household income (dollars)',
#        'Mean household income (dollars)'],
#       dtype='object')

# %%
omg['Mean household income (dollars)'] = omg['Mean household income (dollars)'].replace('N', '0')

# %%
omg['Median household income (dollars)'] = omg['Median household income (dollars)'].replace('-', '0')

# %%
omg.dtypes
# Out:
# Zipcode                                int64
# score                                  int64
# index                                  int64
# Population 16 years and over           int32
# Employed                             float64
# Unemployed                             int64
# Median household income (dollars)      int64
# Mean household income (dollars)        int64
# dtype: object

# %%
omg['Population 16 years and over'] = omg['Population 16 years and over'].str.replace(',', '').astype('int')

# %%
omg['Employed'] = omg['Employed'].astype(np.int64)

# %%
omg['Unemployed'] = omg['Unemployed'].str.replace(',', '').astype(np.int64)

# %%
omg['Median household income (dollars)'] = omg['Median household income (dollars)'].str.replace(',', '').astype(np.int64)

# %%
omg['Mean household income (dollars)'] = omg['Mean household income (dollars)'].str.replace(',', '').astype(np.int64)

# %%
omg.to_csv('corr_clean.csv')

# %%
corr = pd.read_csv('corr_clean.csv')

# %%
corr
# Out:
#     Unnamed: 0  Zipcode  score  index  Population 16 years and over  Employed  \
# 0            0    37072     15      1                         26286     16322
# 1            1    37076     25      2                         31301     21257
# 2            2    37115     30      3                         33647     21552
# 3            3    37138     20      4                         19096     12334
# 4            4    37189      0      5                          3338      2324
# 5            5    37201      5      6                          1443       971
# 6            6    37203     25      7                         17629     12873
# 7            7    37204     10      8                         14195     10803
# 8            8    37205      5      9                         21762     13463
# 9            9    37206     20     10                         23490     17719
# 10          10    37207     20     11                         31065     21146
# ...

# %%
df = corr.drop(columns={'Unnamed: 0', 'index'})

# %%
df.corr()
# Out:
#                                     Zipcode     score  \
# Zipcode                            1.000000 -0.254713
# score                             -0.254713  1.000000
# Population 16 years and over      -0.263668  0.632301
# Employed                          -0.224034  0.624735
# Unemployed                        -0.232019  0.661184
# Median household income (dollars)  0.110732 -0.482628
# Mean household income (dollars)    0.177173 -0.484545
#
#                                    Population 16 years and over  Employed  \
# Zipcode                                               -0.263668 -0.224034
# score                                                  0.632301  0.624735
# Population 16 years and over                           1.000000  0.994148
# Employed                                               0.994148  1.000000
# Unemployed                                             0.923943  0.914689
# Median household income (dollars)                     -0.105418 -0.106828
# ...

# %%
df.to_csv('df_for_dash.csv')

# %%
bottom_5 = df.sort_values('score').head(5)

# %%
bottom_5.plot(x='Zipcode', y=['Population 16 years and over','Unemployed','Mean household income (dollars)'], kind='bar')
# Out:
# <Axes: xlabel='Zipcode'>

# %%
bottom_5.to_csv('bottom5.csv')

# %%
top_5 = df.sort_values('score', ascending=False).head(5)

# %%
top_5.plot(x='Zipcode', y=['Population 16 years and over','Unemployed','Mean household income (dollars)'], kind='bar')
# Out:
# <Axes: xlabel='Zipcode'>

# %%
top_5.to_csv('top5.csv')

# %%
tdf = df.transpose()

# %%
tdf = tdf.reset_index()

# %%
tdf.columns = tdf.iloc[0]

# %%
tdf = tdf.iloc[1:]

# %%
tdf.to_csv('tdf_for_dash.csv')

# %%
tdf
# Out:
# 0                            Zipcode  37072  37076  37115   37138   37189  \
# 1                              score     15     25     30      20       0
# 2       Population 16 years and over  26286  31301  33647   19096    3338
# 3                           Employed  16322  21257  21552   12334    2324
# 4                         Unemployed    918    805   1438     234     123
# 5  Median household income (dollars)  72370  68894  55313   87465   88804
# 6    Mean household income (dollars)  94674  87509  69650  112166  108107
#
# 0   37201  37203   37204   37205  ...  37213  37214   37215  37216  37217  \
# 1       5     25      10       5  ...     10     15      15     20     10
# 2    1443  17629   14195   21762  ...     22  26397   18696  16092  24380
# 3     971  12873   10803   13463  ...     13  18643   11798  11624  17265
# 4       0    431     196     238  ...      0    678     217    428    908
# 5  106460  63834  104987  136100  ...      0  71582  148074  74693  57084
# ...

# %%
df
# Out:
#     Zipcode  score  Population 16 years and over  Employed  Unemployed  \
# 0     37072     15                         26286     16322         918
# 1     37076     25                         31301     21257         805
# 2     37115     30                         33647     21552        1438
# 3     37138     20                         19096     12334         234
# 4     37189      0                          3338      2324         123
# 5     37201      5                          1443       971           0
# 6     37203     25                         17629     12873         431
# 7     37204     10                         14195     10803         196
# 8     37205      5                         21762     13463         238
# 9     37206     20                         23490     17719         898
# 10    37207     20                         31065     21146        1181
# 11    37208     30                         17880     11165         687
# ...

# %%
project = gpd.read_file('project_zips.geojson')

# %%
project
# Out:
#       zip objectid         po_name      shape_stlength        shape_starea  \
# 0   37072       46  GOODLETTSVILLE  2648.6850248323294    416047.455078125
# 1   37072       45  GOODLETTSVILLE  9724.5061842441155  3337338.4436035156
# 2   37072       47  GOODLETTSVILLE  225242.45424953851  1094968706.7701416
# 3   37076       53       HERMITAGE  291751.42832600401  983805973.83410645
# 4   37076       52       HERMITAGE  3786.7098050626546  675823.34777832031
# 5   37115        1         MADISON  178783.02488886821  596553400.57885742
# 6   37138       51     OLD HICKORY  133803.10728562382  398431173.90905762
# 7   37189       50    WHITES CREEK  212443.88846785942  693260660.63964844
# 8   37201       14       NASHVILLE  25670.555742711778   11151362.94934082
# 9   37203       33       NASHVILLE  91285.438580354588   120649702.5546875
# 10  37204        9       NASHVILLE  93180.292250425613  200664795.51708984
# ...

# %%
project = project.drop(index={0,1,3}).reset_index()

# %%
project = project.drop(columns={'index'})

# %%
project = project.drop(index={10}).reset_index()

# %%
project = project.drop(columns={'index'})

# %%
project.to_file('icon_zips.geojson')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#     Zipcode  score  Population 16 years and over  Employed  Unemployed  \
# 0     37072     15                         26286     16322         918
# 1     37076     25                         31301     21257         805
# 2     37115     30                         33647     21552        1438
# 3     37138     20                         19096     12334         234
# 4     37189      0                          3338      2324         123
# 5     37201      5                          1443       971           0
# 6     37203     25                         17629     12873         431
# 7     37204     10                         14195     10803         196
# 8     37205      5                         21762     13463         238
# 9     37206     20                         23490     17719         898
# 10    37207     20                         31065     21146        1181
# 11    37208     30                         17880     11165         687
# ...

# %%
project.zip = project.zip.astype('int')

# %%
project.dtypes
# Out:
# zip                  int32
# objectid            object
# po_name             object
# shape_stlength      object
# shape_starea        object
# geometry          geometry
# dtype: object

# %%
byzip = project.merge(df, left_on='zip', right_on='Zipcode', how='inner')

# %%
byzip.to_file('heatmaptable.geojson')

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
byzip.plot(column='Mean household income (dollars)', cmap='PuRd', linewidth=0.8, ax=ax)
ax.set_title('Heatmap of Income by Zip Code')
plt.savefig('inc_heat_pink.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
byzip.plot(column='Unemployed', cmap='PuRd', linewidth=0.8, ax=ax)
ax.set_title('Heatmap of Unemployed by Zip Code')
plt.savefig('unemp_heat_pink.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
byzip.plot(column='Population 16 years and over', cmap='PuRd', linewidth=0.8, ax=ax)
ax.set_title('Heatmap of Population by Zip Code')
plt.savefig('pop_heat_pink.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
byzip.plot(column='Unemployed', cmap='Purples', linewidth=0.8, ax=ax)
ax.set_title('Heatmap of Unemployed by Zip Code')

plt.show()

# %%
byzip.to_csv('demo_shape_by_zip.csv')

# %%
by_zip.plot()
# Out:
# <Axes: >

# %% [markdown]
# leg_kwds = {'title': 'Zipcodes', 'loc': 'upper left',
#             'bbox_to_anchor': (1, 1), 'ncol': 2}
#
# by_zip.plot(column = 'Zipcode', figsize=(12, 12),
#               edgecolor = 'black',
#               legend = True, legend_kwds = leg_kwds,
#               cmap = 'Purples')
# plt.savefig('by_zip_purple.png')
# plt.show();

# %%
ax = project.plot(figsize = (15, 15), cmap = 'Purples')
by_zip.plot( ax = ax, column = 'zip')
plt.savefig('by_zip_purple.png')
plt.show();
